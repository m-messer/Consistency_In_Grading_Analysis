# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Interview Code Analysis

# %%
blue = (148/255, 203/255, 236/255)
sns.set(style="whitegrid")

# %%
df = pd.read_csv('data/interview_code_counts.csv')
df
# Out:
#    Folder                                            Name  Description  \
# 0   Codes               Became more consistent throughout          NaN
# 1   Codes                        Did not notice duplicate          NaN
# 2   Codes                           Did not review grades          NaN
# 3   Codes         Did not think they were that consistent          NaN
# 4   Codes                       Does not like inhertiance          NaN
# 5   Codes             Envirionment did not have an effect          NaN
# 6   Codes                    Environment affected grading          NaN
# 7   Codes                              First time grading          NaN
# 8   Codes                                  Graded at home          NaN
# 9   Codes                         Graded batch in one day          NaN
# 10  Codes                                   Graded before          NaN
# 11  Codes            Graded correctness then code quality          NaN
# 12  Codes                              Graded each setion          NaN
# 13  Codes  Graded entire assignment before moving to next          NaN
# 14  Codes                      Graded in busy environment          NaN
# 15  Codes                 Graded until they felt fatigued          NaN
# 16  Codes                       Graded when had free time          NaN
# 17  Codes                        Mood did not have effect          NaN
# 18  Codes                     Mood may have had an effect          NaN
# 19  Codes           Noticed a duplication between batches          NaN
# 20  Codes                     Noticed similar submissions          NaN
# 21  Codes                                       One break          NaN
# 22  Codes                                 Reviewed grades          NaN
# 23  Codes                                          Rushed          NaN
# 24  Codes                 Split grading into small groups          NaN
# 25  Codes                    Thought they were consistent          NaN
# 26  Codes                       Thought they were lenient          NaN
# 27  Codes             Time of day does not have an effect          NaN
# 28  Codes           Time of day may have effected grading          NaN
#
#     Sources  References
# 0         6           6
# 1        21          21
# 2         5           5
# 3         3           3
# 4         1           1
# 5        19          19
# 6         8           8
# 7         2           2
# 8         1           1
# 9         1           1
# 10        1           1
# 11        1           1
# 12        4           4
# 13       24          24
# 14        2           2
# 15        1           1
# 16        7           7
# 17       12          12
# 18        7           7
# 19        6           6
# 20       16          16
# 21        1           2
# 22       20          20
# 23        1           1
# 24       19          19
# 25       24          24
# 26        1           1
# 27        9           9
# 28        9           9

# %%
code_plt = sns.barplot(df, y='Name', x='Sources', color=blue)
code_plt.set(ylabel='Name', xlabel='Count')
code_plt.get_figure().savefig('plots/interview_code_counts.pdf', bbox_inches='tight')
